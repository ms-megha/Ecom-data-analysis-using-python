# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#load data
dataset= pd.read_excel("Superstore_USA.xlsx")
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %% [markdown]
# #check null value

# %%
#dataset.isnull().sum()

# %% [markdown]
# #fill null value

# %%
dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(), inplace=True)

# %% [markdown]
# #check duplicate

# %%
#dataset.duplicated().sum()

# %% [markdown]
# #analize Order Priority

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
dataset["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
dataset["Order Priority"]=dataset["Order Priority"].replace("Critical ", "Critical")

# %%
plt.figure(figsize=(6,3))
sns.countplot(x="Order Priority", data = dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.png")
plt.show()

# %% [markdown]
# #Ship Mode

# %%
dataset["Ship Mode"].value_counts()
x=dataset["Ship Mode"].value_counts().index
y=dataset["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(6,3))
plt.pie(y, labels=x, autopct="%0.2f%%", startangle=30)
plt.legend(loc="best")
plt.title("Ship Mode")
plt.savefig("Count of Ship Mode.png")
plt.show()

# %% [markdown]
# #product category according to shiping mode

# %%
plt.figure(figsize=(6,3))
sns.countplot(x="Ship Mode", data = dataset, hue="Product Category")
plt.title("Count of Ship Mode based on Product Category")
plt.savefig("Count of Ship Mode based on Product Category.png")
plt.show()

# %% [markdown]
# #Customer Segment

# %%
plt.figure(figsize=(6,3))
sns.countplot(x="Customer Segment", data = dataset)
plt.title("Count of Customer Segment")
plt.savefig("Count of Customer Segment.png")
plt.show()

# %% [markdown]
# #Product Category

# %%
dataset["Product Category"].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.countplot(x="Product Category", data = dataset)
plt.title("Count of Product Category")
plt.savefig("Count of Product Category.png")
plt.show()

# %% [markdown]
# #Product Sub-Category according to Product Category

# %%
#Office Supplies

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Product Category", data = dataset[dataset["Product Category"]=="Office Supplies"], hue="Product Sub-Category")
plt.title("Count of Product Category according to Office Supplies")
plt.savefig("Count of Product Category according to Office Supplies.png")
plt.show()

# %%
#Technology

# %%
plt.figure(figsize=(10,3))
sns.countplot(x="Product Category", data = dataset[dataset["Product Category"]=="Technology"], hue="Product Sub-Category")
plt.title("Count of Product Category according to Technology")
plt.savefig("Count of Product Category according to Technology.png")
plt.show()

# %%
#Furniture

# %%
plt.figure(figsize=(10,3))
sns.countplot(x="Product Category", data = dataset[dataset["Product Category"]=="Furniture"], hue="Product Sub-Category")
plt.title("Count of Product Category according to Furniture")
plt.savefig("Count of Product Category according to Furniture.png")
plt.show()

# %% [markdown]
# #Order Date

# %%
#dataset.info()

# %%
dataset["Order Year"]=dataset["Order Date"].dt.year

# %%
dataset["Order Year"].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.countplot(x="Order Year", data = dataset)
plt.title("Count of Order according to Year")
plt.savefig("Count of Order according to Year.png")
plt.show()

# %% [markdown]
# #Profit according to product category

# %%
plt.figure(figsize=(4,3))
sns.barplot(x="Product Category", y="Profit", data=dataset, estimator='sum')
plt.title("Total Profit by Product Category")
plt.savefig("Total Profit by Product Category.png")
plt.show()

# %% [markdown]
# #State or Province

# %%
dataset["State or Province"].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
#dataset.info()

# %% [markdown]
# #Product Base Margin based on Product Category

# %%
plt.figure(figsize=(6,3))
sns.barplot(x="Product Category", y="Product Base Margin", data = dataset, estimator='sum')
plt.title("Product Base Margin based on Product Category")
plt.savefig("Product Base Margin based on Product Category.png")
plt.show()
