# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#load data
dataset= pd.read_excel("Superstore_USA.xlsx")
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# #find missing value

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# #fill missing value

# %%
dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(), inplace=True)
# Out:
# C:\Users\MEGHA\AppData\Local\Temp\ipykernel_5296\2786864021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(), inplace=True)

# %% [markdown]
# #Order Priority analsis

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = "Order Priority" , data = dataset)
plt.title("Count of order priority")
plt.savefig("Count of order priority.png")    #save chart
plt.show()

# %%
#dataset["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %% [markdown]
# #data clining ("Critical", "Critical ")

# %%
#dataset["Order Priority"] = dataset["Order Priority"].replace("Critical ", "Critical")

# %% [markdown]
# #shipping mode analysis

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = dataset["Ship Mode"].value_counts().index
y = dataset["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels = x, startangle=60, autopct="%0.2f%%")
plt.legend(loc=2)
plt.title("Ship Mode")
plt.savefig("Ship Mode.png")    #save chart
plt.show()

# %% [markdown]
# #product category analysis using ship mode

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode", data=dataset, hue="Product Category")
plt.show()

# %% [markdown]
# #customer segment

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment", data=dataset)
plt.show()

# %% [markdown]
# #product category

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Product Category", data=dataset)
plt.show()

# %%
plt.figure(figsize=(9,4))
sns.countplot(x="Product Category", data=dataset[dataset["Product Category"]=="Office Supplies"], hue="Product Sub-Category")
plt.show()
